# %% [markdown]
# ## Basic of tag
#
# - Example
#
# ```
# <span style="font-size: 20px;font-weight:bold">Hell world</span>
# ```
#
# - Preview
#
# <span style="font-size: 20px;font-weight:bold">Hell world</span>
#
# - tag: span
# - attribute: style="font-size: 20px;font-weight:bold"
#     - Additional info
#     - name/value format
#
# https://www.w3schools.com/html/html_attributes.asp

# %% [markdown]
# ## What is DOM (Document Object Model)
#
# [Mozilla Define](https://developer.mozilla.org/ko/docs/Web/API/Document_Object_Model/Introduction)
#
# - Programming Interface for HTML, XML (Can easily read, create, update, delete contents)
# - Converted from document to tree data-structure!
#
# ### HTML
#
# <img width="721" alt="스크린샷 2022-11-19 19 53 04" src="https://user-images.githubusercontent.com/16532326/202847128-cba49b7a-a96e-4151-bf10-6e351226201f.png">
#
# - Open chrome developer tool
#
# ### DOM
#
# <img width="480" height="auto" src="https://user-images.githubusercontent.com/16532326/202847294-1aa04b39-c3c3-4969-bc70-ec1aa989ee93.jpg"/>
#
# ```
# document.children
# ## result
# childElementCount: 2
# childNodes: NodeList(3) [head, text, body]
# children: HTMLCollection(2)
#     0: head
#     1: body
# length: 2
# [[Prototype]]: HTMLCollection
# classList: DOMTokenList [value: '']
# ```
#
# [DOM viewer](http://bioub.github.io/dom-visualizer/)
#
# [Youtube tutorial link](https://youtu.be/ipkjfvl40s0)

# %% [markdown]
# ## What is Xpath
#
# - Query language that navigating in HTML/XML documents ([Reference](https://ko.wikipedia.org/wiki/XPath))
#
# [Query examples](https://www.w3schools.com/xml/xpath_syntax.asp)
#
# [Youtube tutorial link](https://youtu.be/U-MZJ6rbqi4)

# %% [markdown]
# ## CSS selector
#
# [CSS selector examples](https://www.w3schools.com/csSref/css_selectors.php)

# %%
# !pip3 install selenium==4.6.0
# !pip3 install webdriver-manager==3.8.5
# Out:
# Requirement already satisfied: selenium==4.6.0 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (4.6.0)
# Requirement already satisfied: trio~=0.17 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from selenium==4.6.0) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from selenium==4.6.0) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from selenium==4.6.0) (2022.9.24)
# Requirement already satisfied: urllib3[socks]~=1.26 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from selenium==4.6.0) (1.26.11)
# Requirement already satisfied: outcome in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (1.2.0)
# Requirement already satisfied: sortedcontainers in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (1.10)
# Requirement already satisfied: idna in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (1.0.4)
# Requirement already satisfied: sniffio in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium==4.6.0) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium==4.6.0) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from urllib3[socks]~=1.26->selenium==4.6.0) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.6.0) (0.14.0)
# Requirement already satisfied: webdriver-manager==3.8.5 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (3.8.5)
# Requirement already satisfied: python-dotenv in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager==3.8.5) (0.21.0)
# Requirement already satisfied: packaging in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager==3.8.5) (21.3)
# Requirement already satisfied: requests in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager==3.8.5) (2.28.1)
# Requirement already satisfied: tqdm in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager==3.8.5) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from packaging->webdriver-manager==3.8.5) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager==3.8.5) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager==3.8.5) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager==3.8.5) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/stories2/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager==3.8.5) (2022.9.24)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.core.utils import ChromeType
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

import os

from IPython import display
from base64 import b64decode

chrome_service = Service(ChromeDriverManager().install())

# %%
# Get environment variables
IS_GITHUB_ACTION = os.getenv('IS_GITHUB_ACTION')

# %%
chrome_options = Options()
if IS_GITHUB_ACTION:
    options = [
        "--headless",
        "--disable-gpu",
        "--window-size=1920,1080",
        "--ignore-certificate-errors",
        "--disable-extensions",
        "--no-sandbox",
        "--disable-dev-shm-usage"
    ]
    user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'    
    chrome_options.add_argument('user-agent={0}'.format(user_agent))
    for option in options:
        chrome_options.add_argument(option)

# %% [markdown]
# https://stackoverflow.com/a/54433282
#
# Some sites require user agent field in request header

# %%
# !ls -al
# Out:
# total 189192
# drwxr-xr-x  33 stories2  staff      1056 12 24 11:02 .
# drwxr-xr-x@ 57 stories2  staff      1824 12 24 00:18 ..
# drwxr-xr-x  16 stories2  staff       512 12 24 11:02 .git
# drwxr-xr-x   3 stories2  staff        96 11 19 23:03 .github
# -rw-r--r--   1 stories2  staff      7745 12 10 23:01 .gitignore
# drwxr-xr-x   8 stories2  staff       256 12 10 19:22 .ipynb_checkpoints
# -rw-r--r--   1 stories2  staff    498880 11 26 20:49 Asiana covid info crawler.ipynb
# -rw-r--r--   1 stories2  staff   6062937 12 24 11:02 Crawl go-tokyo multi process, multi threading.ipynb
# -rw-r--r--   1 stories2  staff  15546932 12 10 21:03 Crawl go-tokyo.ipynb
# -rw-r--r--   1 stories2  staff     84692 11 26 21:43 Hotels combine crawler.ipynb
# -rw-r--r--   1 stories2  staff      1065 11  6 11:29 LICENSE
# -rw-r--r--   1 stories2  staff       856 11 20 00:31 README.md
# -rw-r--r--   1 stories2  staff    213358 12 18 02:05 Skyscanner covid info crawler.ipynb
# drwxr-xr-x   4 stories2  staff       128 12 11 01:29 __pycache__
# -rw-r--r--   1 stories2  staff    204929 12 18 00:45 areaCrawlingResult.json
# -rwxr-xr-x   1 stories2  staff  16535288 11  6 12:40 chromedriver
# -rw-r--r--   1 stories2  staff  12188160 12 18 02:05 chromedriver.exe
# -rw-r--r--@  1 stories2  staff    767504 11 13 00:12 covid.skyscanner.json
# -rw-r--r--@  1 stories2  staff    727948 11 13 00:14 covid.skyscanner.vaccinated.json
# drwxr-xr-x   8 stories2  staff       256 11 13 00:28 crawl-venv
# -rw-r--r--   1 stories2  staff     79934 11 27 10:35 crawling_flow.png
# -rw-r--r--   1 stories2  staff   3171636 12 24 10:19 file_2022-12-24_10-09-06_814828.log
# -rw-r--r--   1 stories2  staff    549915 12 24 10:24 go-tokyo-crawling-result-with-content-detail.csv
# -rw-r--r--   1 stories2  staff       102 12 24 10:31 go-tokyo-crawling-result.csv
# -rw-r--r--   1 stories2  staff      7794 12 11 01:28 goTokyoMultiProcess.py
# -rw-r--r--   1 stories2  staff       202 11  6 12:44 index.py
# -rw-r--r--   1 stories2  staff      1056 12  7 00:21 multiTask.ipynb
# -rw-r--r--   1 stories2  staff       242 12  7 00:22 multiTask.py
# -rw-r--r--   1 stories2  staff     10341 12 18 00:45 placeAndUrlList.json
# -rw-r--r--   1 stories2  staff       841 12 18 02:05 requirements.txt
# -rw-r--r--   1 stories2  staff  20779445 11 26 23:06 screenshot.png
# -rw-r--r--   1 stories2  staff  18339567 11 26 23:07 selenium_full_screenshot.png
# drwxr-xr-x  82 stories2  staff      2624 12 11 01:47 src

# %%
# !pwd
# Out:
# /Users/stories2/Documents/GitHub/python-data-crawler

# %%
# !cd

# %%
my_dir=!pwd

# %%
my_dir[0]
# Out:
# '/Users/stories2/Documents/GitHub/python-data-crawler'

# %% [markdown]
# ```
# ## for windows
# browser = webdriver.Chrome(f'{my_dir[0]}\\chromedriver.exe')
# ```

# %%
# browser = webdriver.Chrome(f'{my_dir[0]}/chromedriver')    
browser = webdriver.Chrome(service=chrome_service, options=chrome_options)
browser.set_window_size(1920, 1080)
browser.get('https://flyasiana.com/C/KR/KO/contents/entry-restrictions')
# browser.get('https://www.skyscanner.co.kr/travel-restrictions/%EB%8C%80%EB%A7%8C/29475323?origin=29475329#MapContainer')

# %%
display.Image(b64decode(browser.find_element(By.TAG_NAME, 'body').screenshot_as_base64))

# %%
browser.find_element(By.CSS_SELECTOR, '#careplus > div > div.main_site > h3').text
# Out:
# '국가별 입국 제한 안내'

# %% [markdown]
# ### Visualize crawling target as image

# %%
display.Image(b64decode(browser.find_element(By.CSS_SELECTOR, '#careplus > div > div.cms_wrap > div.cms-cont > div').screenshot_as_base64))

# browser.find_element_by_css_selector('#careplus > div > div.cms_wrap > div.cms-cont > div').screenshot_as_base64

# %% [markdown]
# ![다운로드 (1)](https://user-images.githubusercontent.com/16532326/209417853-2291c54d-07e1-47de-850c-2c0e4179f0e9.png)

# %% [markdown]
# ### Crawling country list

# %%
countryTable = browser.find_element(By.CSS_SELECTOR, '#careplus > div > div.cms_wrap > div.cms-cont > div')\
    .find_elements(By.CSS_SELECTOR, 'table')[0]
# for tr in trArry:
#     print(tr.get_attribute('innerHTML'))
# countryTable.get_attribute('innerHTML')
# for tr in countryTable.find_elements_by_tag_name('tr'):
#     print(tr.text)
    
countryName = [x.text for x in countryTable.find_elements(By.TAG_NAME, 'tr')][1:]
countryName
# trArry.find_elents_by_css_selector('tr')
# Out:
# ['일본', '중국', '홍콩', '싱가포르', '인도네시아', '필리핀', '미국', '사이판']

# %% [markdown]
# ### Crawl that country Covid-19 entry restrictions info

# %%
countryInfo = browser.find_element(By.CSS_SELECTOR, '#careplus > div > div.cms_wrap > div.cms-cont > div > table:nth-child(2) > tbody')

#.get_attribute('innerHTML')
#.text

# %%
tableResult = []

# %%
idx = 0;
for tr in countryInfo.find_elements(By.TAG_NAME, 'tr'):
    print(f'\n{countryName[idx]}')
#     print(tr.text)
    row = []
    for td in tr.find_elements(By.TAG_NAME, 'td'):
        text = td.text
        print(td.text, end=", ")
        try:
#             print(td.get_attribute('innerHTML'), 'test', )
#             aTag = td.find_element_by_tag_name('a')
#             if aTag is not None:
#                 print(a.get_attribute('href'))
            print(td.find_element(By.TAG_NAME, 'a').get_attribute('href'))
            text = text + ' ' + td.find_element(By.TAG_NAME, 'a').get_attribute('href')
        except:
            print('', end="")
        row.append(text)
    idx += 1
    tableResult.append(row)
# Out:
# 일본
# , X, O, O
# (백신 3차 접종 X), [VISIT JAPAN WEB], https://vjw-lp.digital.go.jp/
# △
# (출발 지역별 상이), [일본 정부 안내사항], https://www.mofa.go.jp/ca/fna/page4e_001053.html
#
# 중국
# , O, X, O, O
# [건강 QR 코드]
# (녹색 QR 필수)
# [세관신고서], https://hrhk.cs.mfa.gov.cn/H5/
# 시설격리 5일
# + 3일 자가모니터링
# (지역별 상이), [주한중국대사관 안내사항], http://kr.china-embassy.gov.cn/kor/lsfw/
#
# 홍콩
# , △
# [안내사항], https://www.immd.gov.hk/eng/services/visas/visit-transit/visit-visa-entry-permit.html
# O
# (홍콩 거주자 제외), O, [건강상태신고서]
# (녹색 QR 필수), https://www.chp.gov.hk/hdf/
# X, [홍콩 정부 안내사항], https://www.coronavirus.gov.hk/eng/inbound-travel.html
#
# 싱가포르
# , X, O, X
# (백신 미접종자 O), [SG Arrival Card], https://eservices.ica.gov.sg/sgarrivalcard/
# X, [싱가포르 정부 안내사항], https://www.ica.gov.sg/enter-transit-depart/entering-singapore
#
# 인도네시아
# , △, O, X, [Peduli Lindungi]
# [전자세관신고], https://www.pedulilindungi.id/
# X, 건강상 미접종자
# 음성확인서 필요 (5일 격리)
# [인도네시아 정부 안내사항], https://www.imigrasi.go.id/en/covid19/#1621501651158-8e7bbdc3-bbb8
#
# 필리핀
# , △
# [안내사항], https://dfa.gov.ph/list-of-countries-for-21-day-visa
# O, X
# (백신 미접종자 O), [eARRIVAL CARD]
# 또는
# [eTravel], https://www.onehealthpass.com.ph/
# △
# (백신 미접종자 양성 판정시 격리), 격리 비용 자부담
# [필리핀 관광청 안내], https://philippines.travel/safetrip#inboundadvisory
#
# 미국
# , X, O
# (시민권자, 영주권자 이민비자 제외), X, X, X, [질병통제센터 안내사항], https://www.cdc.gov/coronavirus/2019-ncov/travelers/international-travel-during-covid19.html
#
# 사이판
# , X, X, X,

# %%
# !pip3 install tabletext==0.1
# Out:
# Collecting tabletext==0.1
#   Using cached tabletext-0.1.tar.gz (6.1 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       error in tabletext setup command: use_2to3 is invalid.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
tableResult
# Out:
# [['',
#   'X',
#   'O',
#   'O\n(백신 3차 접종 X)',
#   '[VISIT JAPAN WEB] https://vjw-lp.digital.go.jp/',
#   '△\n(출발 지역별 상이)',
#   '[일본 정부 안내사항] https://www.mofa.go.jp/ca/fna/page4e_001053.html'],
#  ['',
#   'O',
#   'X',
#   'O',
#   'O\n[건강 QR 코드]\n(녹색 QR 필수)\n[세관신고서] https://hrhk.cs.mfa.gov.cn/H5/',
#   '시설격리 5일\n+ 3일 자가모니터링\n(지역별 상이)',
#   '[주한중국대사관 안내사항] http://kr.china-embassy.gov.cn/kor/lsfw/'],
#  ['',
#   '△\n[안내사항] https://www.immd.gov.hk/eng/services/visas/visit-transit/visit-visa-entry-permit.html',
#   'O\n(홍콩 거주자 제외)',
#   'O',
#   '[건강상태신고서]\n(녹색 QR 필수) https://www.chp.gov.hk/hdf/',
#   'X',
#   '[홍콩 정부 안내사항] https://www.coronavirus.gov.hk/eng/inbound-travel.html'],
#  ['',
#   'X',
#   'O',
#   'X\n(백신 미접종자 O)',
#   '[SG Arrival Card] https://eservices.ica.gov.sg/sgarrivalcard/',
#   'X',
#   '[싱가포르 정부 안내사항] https://www.ica.gov.sg/enter-transit-depart/entering-singapore'],
#  ['',
#   '△',
#   'O',
#   'X',
#   '[Peduli Lindungi]\n[전자세관신고] https://www.pedulilindungi.id/',
#   'X',
#   '건강상 미접종자\n음성확인서 필요 (5일 격리)\n[인도네시아 정부 안내사항] https://www.imigrasi.go.id/en/covid19/#1621501651158-8e7bbdc3-bbb8'],
#  ['',
#   '△\n[안내사항] https://dfa.gov.ph/list-of-countries-for-21-day-visa',
#   'O',
#   'X\n(백신 미접종자 O)',
#   '[eARRIVAL CARD]\n또는\n[eTravel] https://www.onehealthpass.com.ph/',
#   '△\n(백신 미접종자 양성 판정시 격리)',
#   '격리 비용 자부담\n[필리핀 관광청 안내] https://philippines.travel/safetrip#inboundadvisory'],
#  ['',
#   'X',
#   'O\n(시민권자, 영주권자 이민비자 제외)',
#   'X',
#   'X',
#   'X',
#   '[질병통제센터 안내사항] https://www.cdc.gov/coronavirus/2019-ncov/travelers/international-travel-during-covid19.html'],
#  ['', 'X', 'X', 'X']]

# %% [markdown]
# ### Post processing
#
# - Add country name to each first col

# %%
idx = 0
for country in countryName:
    tableResult[idx][0] = country
    idx = idx + 1
tableResult[0]
# Out:
# ['일본',
#  'X',
#  'O',
#  'O\n(백신 3차 접종 X)',
#  '[VISIT JAPAN WEB] https://vjw-lp.digital.go.jp/',
#  '△\n(출발 지역별 상이)',
#  '[일본 정부 안내사항] https://www.mofa.go.jp/ca/fna/page4e_001053.html']

# %% [markdown]
# - Make each rows have same col count

# %% [markdown]
# In

# %%
tableResult[5]
# Out:
# ['필리핀',
#  '△\n[안내사항] https://dfa.gov.ph/list-of-countries-for-21-day-visa',
#  'O',
#  'X\n(백신 미접종자 O)',
#  '[eARRIVAL CARD]\n또는\n[eTravel] https://www.onehealthpass.com.ph/',
#  '△\n(백신 미접종자 양성 판정시 격리)',
#  '격리 비용 자부담\n[필리핀 관광청 안내] https://philippines.travel/safetrip#inboundadvisory']

# %%
tableResult[5][2:2] = [tableResult[5][2]]
tableResult[5]
# Out:
# ['필리핀',
#  '△\n[안내사항] https://dfa.gov.ph/list-of-countries-for-21-day-visa',
#  'O',
#  'O',
#  'X\n(백신 미접종자 O)',
#  '[eARRIVAL CARD]\n또는\n[eTravel] https://www.onehealthpass.com.ph/',
#  '△\n(백신 미접종자 양성 판정시 격리)',
#  '격리 비용 자부담\n[필리핀 관광청 안내] https://philippines.travel/safetrip#inboundadvisory']

# %%
tableResult[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/ss/yh5plwxn7316ftskgbhrp6wh0000gn/T/ipykernel_29528/4084472106.py in <module>
# ----> 1 tableResult[8]
#
# IndexError: list index out of range

# %%
tableResult[8][2:2] = [*tableResult[7][2:4]]
tableResult[8]

# %%
tableResult[8][6:] = [tableResult[7][6]]
tableResult[8]

# %% [markdown]
# Unpacking elements from array https://dev.to/arikaturika/unpacking-python-lists-vs-destructuring-javascript-arrays-3mog

# %%
browser.close()

# %% [markdown]
# ## Display result

# %%
theader = ['국가', '입국 제한', '백신접종증명서', '음성확인서', '사전 신고 절차', '격리', '비고 (상세 조건 확인)']
# tableResult = theader + tableResult

# %%
# !pip3 install pandas==1.5.1

# %%
import pandas as pd
df = pd.DataFrame(tableResult, columns=theader)
df

# %%
df.to_csv('./asiana-covid.csv', sep=',')
